# %% [markdown]
# # Synthetic Water Quality Monitoring Lab
#
# This notebook is a lightweight guide. Run the full pipeline from the repository root first:
#
# ```bash
# python scripts/run_synthetic_water_lab.py
# ```
#
# The generated CSV files will appear in `outputs/results/`.

# %%
from pathlib import Path
import pandas as pd

results = Path('..') / 'outputs' / 'results'
summary = pd.read_json(results / 'synthetic_water_quality_summary.json', typ='series')
summary

# %%
risk = pd.read_csv(results / 'synthetic_treatment_risk.csv')
risk.head(10)
